# %%
# Exibe o grafo do arquivo graph.txt
from functions import visualizar_grafo
visualizar_grafo("grafo.txt")

# %%
from functions import *
np.set_printoptions(threshold=np.inf)

# Utiliza ordem alfabetica para descoberta dos nós
def irrevogavel(inicial, final, matriz_adj):
    descobertos = []
    pais = dict()

    # Inicializa a variavel v
    v = inicial

    if inicial+1 > len(matriz_adj) or final+1 > len(matriz_adj):
        print("Vertice inicial ou final não existe no grafo")
        return []
    while True:
        descobertos.append(v)
        # Encerra o while se o vertice atual for igual ao destino
        if v == final:
            return descobertos, pais
        # Obtém a lista ordenada de vizinhos
        vizinhos = [i for i in obter_vizinhos(v, matriz_adj) if i not in descobertos]
        # Se não houver um vizinho não descoberto, o algoritmo encerra
        if vizinhos == []:
            print("Sem solução!")
            return descobertos, pais
        pais[vizinhos[0]] = v
        # V se torna o vizinho de menor indice
        v = vizinhos[0]

matriz_adj = gerar_matriz_adjacente("grafo.txt")
inicial, final = letter_to_int("G")-1, letter_to_int("S")-1 # Retorna o número correspondente a ordem alfabética -1

descobertos, pais = irrevogavel(inicial, final, matriz_adj)

imprimir_resultado(incrementar(descobertos), usarLetras=True)
# Out:
# Sem solução!
# Ordem de descoberta:  ['G', 'F', 'A', 'B', 'C', 'D', 'E', 'R', 'O', 'L', 'I', 'J', 'M', 'K', 'H']

# %%
visualizar_arvore_de_pais(incrementar(pais), usarLetras=True, titulo="Árvore Irrevogavel")
