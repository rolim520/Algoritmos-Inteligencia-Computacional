# %%
# Exibe o grafo do arquivo graph.txt
from functions import visualizar_grafo
visualizar_grafo("grafo.txt")

# %%
from functions import *
np.set_printoptions(threshold=np.inf)

# Utiliza ordem alfabetica para descoberta dos nós
def A_estrela(inicial, final, matriz_adj, heuristica):
    descobertos = []
    # Conjunto de vertices que não foram explorados
    abertos = []
    # Distancia do inicial até o vertice, considerando somente as arestas
    distancia = dict()
    # Distancia do inicial até o vertice somada a heuristica do vertice até o final
    distancia_h = dict()
    pais = dict()

    # Adiciona todos os vertices no conjunto de abertos
    for vertice in range(len(matriz_adj)):
        if conexo_ao_grafo(vertice, matriz_adj):
            abertos.append(vertice)
            distancia[vertice] = np.inf
    if len(matriz_adj) != len(abertos):
        print("O grafo possui vértices desconexos")

    # Descobre o vertice inicial e zera sua distancia
    descobertos.append(inicial)
    distancia[inicial] = 0
    # Inicializa a distancia+heuristica do vertice inicial
    distancia_h[inicial] = 0 + heuristica[inicial]

    if inicial+1 > len(matriz_adj) or final+1 > len(matriz_adj):
        print("Vertice inicial ou final não existe no grafo")
        return []
    while len(abertos) != 0:
        print("Abertos (v: dist+heur): ", [f"{int_to_letter(i+1)}: {distancia_h[i]}" for i in distancia_h if i in abertos])
        # Obtem o vertice de menor soma da distancia de arestas desde a origem mais a heuristica dele até o destino
        v = abertos.pop(obter_indice_de_menor_metrica(abertos, distancia_h))
        print("Escolhido: ", int_to_letter(v+1))
        # Obtém os vizinhos do vertice v
        vizinhos = [i for i in obter_vizinhos(v, matriz_adj) if i in abertos]
        print("Vizinhos (v: dist+heur):", [f"{int_to_letter(i+1)}: {distancia[v] + matriz_adj[v][i] + heuristica[i]}" for i in vizinhos], "\n")

        for vizinho in vizinhos:
            # Descobre cada vizinho e os adiciona na fila para serem explorados
            descobertos.append(vizinho)
            # Se a distancia encontrada for menor que a guardada, ele substitui a distância
            if distancia[v] + matriz_adj[v][vizinho] < distancia[vizinho]:
                distancia[vizinho] = distancia[v] + matriz_adj[v][vizinho]
                distancia_h[vizinho] = distancia[vizinho] + heuristica[vizinho]
                pais[vizinho] = v
    print(f"Distância da Solução: {distancia[final]}")
    return descobertos, pais

matriz_adj = gerar_matriz_adjacente("grafo.txt")
heuristica = gerar_heuristicas("heuristica.txt")
inicial, final = letter_to_int("G")-1, letter_to_int("S")-1 # Retorna o número correspondente a ordem alfabética

descobertos, pais = A_estrela(inicial, final, matriz_adj, heuristica)

imprimir_resultado(incrementar(descobertos), usarLetras=True)
# Out:
# Abertos (v: dist+heur):  ['G: 35']
# Escolhido:  G
# Vizinhos (v: dist+heur): ['F: 43.0', 'H: 46.0', 'J: 37.0', 'K: 53.0']
#
# Abertos (v: dist+heur):  ['F: 43.0', 'H: 46.0', 'J: 37.0', 'K: 53.0']
# Escolhido:  J
# Vizinhos (v: dist+heur): ['I: 44.0', 'L: 37.0', 'M: 39.0']
#
# Abertos (v: dist+heur):  ['F: 43.0', 'H: 46.0', 'K: 53.0', 'I: 44.0', 'L: 37.0', 'M: 39.0']
# Escolhido:  L
# Vizinhos (v: dist+heur): ['C: 63.0', 'D: 69.0', 'I: 61.0', 'M: 56.0', 'O: 39.0', 'P: 52.0']
#
# Abertos (v: dist+heur):  ['F: 43.0', 'H: 46.0', 'K: 53.0', 'I: 44.0', 'M: 39.0', 'C: 63.0', 'D: 69.0', 'O: 39.0', 'P: 52.0']
# Escolhido:  M
# Vizinhos (v: dist+heur): ['K: 73.0', 'N: 59.0', 'P: 44.0', 'Q: 42.0']
#
# Abertos (v: dist+heur):  ['F: 43.0', 'H: 46.0', 'K: 53.0', 'I: 44.0', 'C: 63.0', 'D: 69.0', 'O: 39.0', 'P: 44.0', 'N: 59.0', 'Q: 42.0']
# Escolhido:  O
# Vizinhos (v: dist+heur): ['P: 55.0', 'R: 57.0', 'S: 41.0']
#
# Abertos (v: dist+heur):  ['F: 43.0', 'H: 46.0', 'K: 53.0', 'I: 44.0', 'C: 63.0', 'D: 69.0', 'P: 44.0', 'N: 59.0', 'Q: 42.0', 'R: 57.0', 'S: 41.0']
# Escolhido:  S
# Vizinhos (v: dist+heur): ['T: 61.0']
#
# Abertos (v: dist+heur):  ['F: 43.0', 'H: 46.0', 'K: 53.0', 'I: 44.0', 'C: 63.0', 'D: 69.0', 'P: 44.0', 'N: 59.0', 'Q: 42.0', 'R: 57.0', 'T: 61.0']
# Escolhido:  Q
# Vizinhos (v: dist+heur): ['P: 49.0', 'T: 44.0']
#
# Abertos (v: dist+heur):  ['F: 43.0', 'H: 46.0', 'K: 53.0', 'I: 44.0', 'C: 63.0', 'D: 69.0', 'P: 44.0', 'N: 59.0', 'R: 57.0', 'T: 44.0']
# Escolhido:  F
# Vizinhos (v: dist+heur): ['A: 54.0', 'I: 44.0']
#
# Abertos (v: dist+heur):  ['H: 46.0', 'K: 53.0', 'I: 44.0', 'C: 63.0', 'D: 69.0', 'P: 44.0', 'N: 59.0', 'R: 57.0', 'T: 44.0', 'A: 54.0']
# Escolhido:  I
# Vizinhos (v: dist+heur): ['A: 68.0', 'B: 59.0']
#
# Abertos (v: dist+heur):  ['H: 46.0', 'K: 53.0', 'C: 63.0', 'D: 69.0', 'P: 44.0', 'N: 59.0', 'R: 57.0', 'T: 44.0', 'A: 54.0', 'B: 59.0']
# Escolhido:  P
# Vizinhos (v: dist+heur): []
#
# Abertos (v: dist+heur):  ['H: 46.0', 'K: 53.0', 'C: 63.0', 'D: 69.0', 'N: 59.0', 'R: 57.0', 'T: 44.0', 'A: 54.0', 'B: 59.0']
# Escolhido:  T
# Vizinhos (v: dist+heur): []
#
# Abertos (v: dist+heur):  ['H: 46.0', 'K: 53.0', 'C: 63.0', 'D: 69.0', 'N: 59.0', 'R: 57.0', 'A: 54.0', 'B: 59.0']
# Escolhido:  H
# Vizinhos (v: dist+heur): ['K: 52.0']
#
# Abertos (v: dist+heur):  ['K: 52.0', 'C: 63.0', 'D: 69.0', 'N: 59.0', 'R: 57.0', 'A: 54.0', 'B: 59.0']
# Escolhido:  K
# Vizinhos (v: dist+heur): ['N: 60.0']
#
# Abertos (v: dist+heur):  ['C: 63.0', 'D: 69.0', 'N: 59.0', 'R: 57.0', 'A: 54.0', 'B: 59.0']
# Escolhido:  A
# Vizinhos (v: dist+heur): ['B: 60.0']
#
# Abertos (v: dist+heur):  ['C: 63.0', 'D: 69.0', 'N: 59.0', 'R: 57.0', 'B: 59.0']
# Escolhido:  R
# Vizinhos (v: dist+heur): ['E: 72.0']
#
# Abertos (v: dist+heur):  ['C: 63.0', 'D: 69.0', 'N: 59.0', 'B: 59.0', 'E: 72.0']
# Escolhido:  B
# Vizinhos (v: dist+heur): ['C: 60.0']
#
# Abertos (v: dist+heur):  ['C: 60.0', 'D: 69.0', 'N: 59.0', 'E: 72.0']
# Escolhido:  N
# Vizinhos (v: dist+heur): []
#
# Abertos (v: dist+heur):  ['C: 60.0', 'D: 69.0', 'E: 72.0']
# Escolhido:  C
# Vizinhos (v: dist+heur): ['D: 65.0']
#
# Abertos (v: dist+heur):  ['D: 65.0', 'E: 72.0']
# Escolhido:  D
# Vizinhos (v: dist+heur): ['E: 66.0']
#
# Abertos (v: dist+heur):  ['E: 66.0']
# Escolhido:  E
# Vizinhos (v: dist+heur): []
#
# Distância da Solução: 41.0
# Ordem de descoberta:  ['G', 'F', 'H', 'J', 'K', 'I', 'L', 'M', 'C', 'D', 'I', 'M', 'O', 'P', 'K', 'N', 'P', 'Q', 'P', 'R', 'S', 'T', 'P', 'T', 'A', 'I', 'A', 'B', 'K', 'N', 'B', 'E', 'C', 'D', 'E']

# %%
visualizar_arvore_de_pais(incrementar(pais), usarLetras=True, titulo="Árvore A*")
